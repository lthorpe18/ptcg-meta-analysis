# %% [markdown]
# # 03 — Weight fitting

# %% [markdown]
# Only begin after the data audit and baseline backtest are accepted.

# %% [markdown]
# Test interpretable parameters sequentially: IRL start weight/decay/floor, then Online recency/half-life, then a small joint grid.

# %% [markdown]
# Prefer a simpler model unless additional parameters materially improve out-of-sample results.
