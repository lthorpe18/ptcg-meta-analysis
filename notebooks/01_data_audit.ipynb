# %% [markdown]
# # 01 — Data audit

# %% [markdown]
# First deliverable: describe what historical Online data is actually available before fitting any model.

# %% [markdown]
# Planned outputs: tournament counts, player counts, classification coverage, event eligibility reasons, and coverage by target IRL-major backtest window.

# %% [markdown]
# Do not choose a classification-coverage threshold until its empirical distribution has been inspected.
