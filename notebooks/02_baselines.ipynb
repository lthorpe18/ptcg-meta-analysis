# %% [markdown]
# # 02 — Baselines

# %% [markdown]
# Planned models: IRL-only, Online-only, 50/50, and an independent reproduction of current Blended v2.1.

# %% [markdown]
# Primary score: Field Accuracy = 100% − 0.5 × sum(abs(predicted share − actual share)).

# %% [markdown]
# Use chronological walk-forward evaluation and treat same-week majors as a correlated prediction cohort.
